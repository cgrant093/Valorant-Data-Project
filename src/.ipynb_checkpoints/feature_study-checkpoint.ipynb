# %% [markdown]
# # Feature study and extract aggregate statistics

# %% [markdown]
# #### Import necessary modules

# %%
import os
import pandas as pd

#from rank_and_position_dfs import get_ranked_df, get_ranked_pos_df 
from graphs import rank_order, plot_avg_value, plot_avg_value_per_position

# %% [markdown]
# ### Make folder paths for data (and potentially a new subfolder)

# %%
def make_folder(folder):
    ## Check whether the specified path exists or not
    isExist = os.path.exists(folder)
    
    if not isExist:
        ## Create a new directory because it does not exist 
        os.makedirs(folder)
        print("The new directory is created!")

# %%
data_path = f'data/'
plot_path = f'plots/'

make_folder(data_path)
make_folder(plot_path)

# %% [markdown]
# ## Get Aggregate Statistics by rank (and position)

# %%
df = pd.read_csv(f'{data_path}cleaned_total_list.csv')

# %% [markdown]
# #### Group by rank

# %%
plot_avg_value('KD', df, plot_path, 'Avg. Kill/Death ratio per match')

# %%
plot_avg_value('KD', df, plot_path, 'Avg. Kill/Death ratio per match')

# %%
plot_avg_value('KD', df, plot_path, 'Avg. Kill/Death ratio per match')

# %%
plot_avg_value('KD', df, plot_path, 'Avg. Kill/Death ratio per match')

# %%
plot_avg_value('avg_assists', df, plot_path, 'Avg. Assists per round')

# %%
plot_avg_value('HS_perc', df, plot_path, 'Avg. Headshot % per match')

# %%
plot_avg_value('avg_ability_usage', df, plot_path, 'Avg. Ability Usage per round')

# %%
plot_avg_value('avg_score', df, plot_path, 'Avg. Combat Score per match')

# %%
plot_avg_value('avg_dmg_made', df, plot_path, 'Avg. Damage Given per round')

# %%
plot_avg_value('avg_dmg_rec', df, plot_path, 'Avg. Damage Received per round')

# %%
plot_avg_value('avg_spent', df, plot_path, 'Avg. Economy Spent per round')

# %%
plot_avg_value('avg_loadout', df, plot_path, 'Avg. Economy Loadout per round')

# %%
plot_avg_value('level', df, plot_path, 'Avg. Account Level')

# %% [markdown]
# #### Also group by position

# %%
plot_avg_value_per_position('KD', df, plot_path, 'Avg. Kill/Death ratio per match')

# %%
plot_avg_value_per_position('avg_assists', df, plot_path, 'Avg. Assists per round')

# %%
plot_avg_value_per_position('HS_perc', df, plot_path, 'Avg. Headshot % per match')

# %%
plot_avg_value_per_position('avg_ability_usage', df, plot_path, 'Avg. Ability Usage per round')

# %%
plot_avg_value_per_position('avg_score', df, plot_path, 'Avg. Combat Score per round')

# %%
plot_avg_value_per_position('avg_dmg_made', df, plot_path, 'Avg. Damage Given per round')

# %%
plot_avg_value_per_position('avg_dmg_rec', df, plot_path, 'Avg. Damage Received per round')

# %%
plot_avg_value_per_position('avg_spent', df, plot_path, 'Avg. Economy Spent per round')

# %%
plot_avg_value_per_position('avg_loadout', df, plot_path, 'Avg. Economy Loadout per round')

# %%
plot_avg_value_per_position('level', df, plot_path, 'Avg. Account Level')
